# %% [markdown]
# # What are the **most** expensive municipalities in Belgium? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area and Land Surface  compered to Average Price

# %%
import matplotlib.pyplot as plt
import pandas as pd 

def expensive_locality(df):


    localities = df['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']
    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=False)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality(df)
print(df_return)

df_return=expensive_locality(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'],color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average Price")
plt.title("Top 10  most expensive localities in Belgium")
plt.gca().invert_yaxis()
plt.show()
# Out:
#           Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 785        Pollare       999000.0      999000.0             993.04
# 549      Buvrinnes       995000.0      995000.0             843.22
# 567      Kasterlee       957000.0      957000.0            1519.05
# 416       Bornival       950000.0      950000.0              37.27
# 775  Borchtlombeek       949000.0      949000.0             794.81
# ..             ...            ...           ...                ...
# 601   Baillonville       115000.0      125000.0             492.32
# 626      Bailièvre       110000.0      110000.0             379.87
# 266      Bléharies       102500.0      102500.0             313.31
# 112      Grandrieu        95000.0       95000.0             840.71
# 724     Asquillies        83500.0       83500.0             237.80
#
# [806 rows x 4 columns]

# %% [markdown]
# # What are the **most** expensive municipalities in Belgium? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area  and Land Surface compered to Average per square meters

# %%
import pandas as pd
import matplotlib.pyplot as plt

def expensive_locality(df):


    localities = df['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    localities = df['Locality'].unique()
    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=False)


    return municipality_stats

df=pd.read_csv("C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv")


df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality(df)
print(df_return)
df_return=expensive_locality(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 most expensive localities in Belgium")
plt.gca().invert_yaxis()
plt.show()
# Out:
#              Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 115            Knokke      688026.36      695000.0            4116.13
# 228     Heist-Aan-Zee      516281.25      472000.0            2730.95
# 486  Louvain-La-Neuve      236000.00      240000.0            2658.99
# 192          Oudergem      567138.92      568400.0            2634.20
# 11             Leuven      426707.32      415000.0            2356.19
# ..                ...            ...           ...                ...
# 730              Hour      340000.00      340000.0             158.88
# 437          Bierwart      395000.00      395000.0             127.46
# 761            Chanly      750000.00      750000.0             122.19
# 734          Kerkhove      225000.00      225000.0              72.91
# 416          Bornival      950000.00      950000.0              37.27
#
# [806 rows x 4 columns]

# %% [markdown]
# # What are the most expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %% [markdown]
# Analysis done on the basis of  Living Area  and Land Surface compered to Average price per squares meters

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv")

def expensive_locality_Wallonia(df):


    localities = df.query("Region == 'Wallonia'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=False)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Wallonia(df)
print(df_return)
df_return=expensive_locality_Wallonia(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 most expensive localities in Wallonia")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                   Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 174       Louvain-La-Neuve       236000.0      240000.0            2658.99
# 3         Fontaine-Valmont       600000.0      600000.0            2264.15
# 289                 Bonlez       734577.8      757889.0            1901.04
# 207      Fontaine-l'evêque       312000.0      345000.0            1799.42
# 297  Couture-Saint-Germain       785000.0      785000.0            1787.50
# ..                     ...            ...           ...                ...
# 369              Papignies       235000.0      235000.0             163.19
# 323                   Hour       340000.0      340000.0             158.88
# 153               Bierwart       395000.0      395000.0             127.46
# 344                 Chanly       750000.0      750000.0             122.19
# 143               Bornival       950000.0      950000.0              37.27
#
# [372 rows x 4 columns]

# %% [markdown]
# # What are the most expensive municipalities in Wallonia? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area and Land Surface  compered to Average Price

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv")

def expensive_locality_Wallonia(df):


    localities = df.query("Region == 'Wallonia'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=False)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Wallonia(df)
print(df_return)

df_return=expensive_locality_Wallonia(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'], color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average_Price")
plt.title("Top 10 most expensive localities in Wallonia")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                   Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 206              Buvrinnes       995000.0      995000.0             843.22
# 143               Bornival       950000.0      950000.0              37.27
# 297  Couture-Saint-Germain       785000.0      785000.0            1787.50
# 345          Céroux-Mousty       760000.0      760000.0             450.72
# 344                 Chanly       750000.0      750000.0             122.19
# ..                     ...            ...           ...                ...
# 231           Baillonville       115000.0      125000.0             492.32
# 246              Bailièvre       110000.0      110000.0             379.87
# 88               Bléharies       102500.0      102500.0             313.31
# 28               Grandrieu        95000.0       95000.0             840.71
# 320             Asquillies        83500.0       83500.0             237.80
#
# [372 rows x 4 columns]

# %% [markdown]
# # What are the most expensive municipalities in Flanders? (Average price, median price, price per square meter)
#
# Analysis done on the basis of  Living Area  and Land Surface compered to Average Price

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv")

def expensive_locality_Flanders(df):


    localities = df.query("Region == 'Falnders'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=False)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Flanders(df)
print(df_return)
df_return=expensive_locality_Flanders(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'], color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average_Price")
plt.title("Top 10 most expensive localities in Flanders")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 404             Pollare      999000.00      999000.0             993.04
# 332           Kasterlee      957000.00      957000.0            1519.05
# 399       Borchtlombeek      949000.00      949000.0             794.81
# 54   Sint-martens-latem      878333.33      845000.0            1305.77
# 393          Middelburg      849000.00      849000.0            1061.25
# ..                  ...            ...           ...                ...
# 410            Heestert      176000.00      176000.0             642.34
# 367            Langdorp      169000.00      169000.0             676.00
# 153            Dadizele      168500.00      168500.0             642.71
# 335               Rekem      129000.00      129000.0             486.79
# 320             Bossuit      118000.00      118000.0             445.28
#
# [413 rows x 4 columns]

# %% [markdown]
# # What are the most expensive municipalities in Flanders? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area and Land Surface compered to Average price per squares meters

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv")

def expensive_locality_Flanders(df):


    localities = df.query("Region == 'Falnders'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=False)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Flanders(df)
print(df_return)

df_return=expensive_locality_Flanders(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 most expensive localities in Flanders")
plt.gca().invert_yaxis()
plt.show()
# Out:
#               Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 77              Knokke      688026.36      695000.0            4116.13
# 135      Heist-Aan-Zee      516281.25      472000.0            2730.95
# 9               Leuven      426707.32      415000.0            2356.19
# 79          Nieuwpoort      375525.64      285000.0            2166.43
# 150           Koksijde      456570.00      377000.0            2076.48
# ..                 ...            ...           ...                ...
# 277  Sint-Eloois-Vijve      475000.00      475000.0             289.28
# 394           Everberg      370000.00      370000.0             285.94
# 220             Kaster      299500.00      299500.0             284.16
# 307         Alveringem      257500.00      257500.0             279.11
# 386           Kerkhove      225000.00      225000.0              72.91
#
# [413 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Belgium? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area and Land Surface  compered to Average  price

# %%
import pandas as pd
import matplotlib.pyplot as plt

def expensive_locality(df):


    localities = df['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    localities = df['Locality'].unique()
    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=True)


    return municipality_stats
df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality(df)
print(df_return)

df_return=expensive_locality(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'],  color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average Price")
plt.title("Top 10 less expensive localities in Belgium")
plt.gca().invert_yaxis()
plt.show()
# Out:
#           Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 724     Asquillies        83500.0       83500.0             237.80
# 112      Grandrieu        95000.0       95000.0             840.71
# 266      Bléharies       102500.0      102500.0             313.31
# 626      Bailièvre       110000.0      110000.0             379.87
# 601   Baillonville       115000.0      125000.0             492.32
# ..             ...            ...           ...                ...
# 775  Borchtlombeek       949000.0      949000.0             794.81
# 416       Bornival       950000.0      950000.0              37.27
# 567      Kasterlee       957000.0      957000.0            1519.05
# 549      Buvrinnes       995000.0      995000.0             843.22
# 785        Pollare       999000.0      999000.0             993.04
#
# [806 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Belgium? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area  and Land Surface compered to Average price per squares meters

# %%
import pandas as pd
import matplotlib.pyplot as plt

def expensive_locality(df):


    localities = df['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    localities = df['Locality'].unique()
    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality(df)
print(df_return)

df_return=expensive_locality(df).head(10).sort_values('Avg_Price_per_SqM',ascending=True)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 less expensive localities in Belgium")
plt.gca().invert_yaxis()
# Out:
#              Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 416          Bornival      950000.00      950000.0              37.27
# 734          Kerkhove      225000.00      225000.0              72.91
# 761            Chanly      750000.00      750000.0             122.19
# 437          Bierwart      395000.00      395000.0             127.46
# 730              Hour      340000.00      340000.0             158.88
# ..                ...            ...           ...                ...
# 11             Leuven      426707.32      415000.0            2356.19
# 192          Oudergem      567138.92      568400.0            2634.20
# 486  Louvain-La-Neuve      236000.00      240000.0            2658.99
# 228     Heist-Aan-Zee      516281.25      472000.0            2730.95
# 115            Knokke      688026.36      695000.0            4116.13
#
# [806 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Wallonia? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area  and Land Surface compered to Average price

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv")
localities_Wallonia= df.query("Region == 'Wallonia'")['Locality'].unique()

def expensive_locality_Wallonia(df):


    localities = df.query("Region == 'Wallonia'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Wallonia(df)
print(df_return)
df_return=expensive_locality_Wallonia(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'], color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average_Price")
plt.title("Top 10 les expensive localities in Wallonia")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                   Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 320             Asquillies        83500.0       83500.0             237.80
# 28               Grandrieu        95000.0       95000.0             840.71
# 88               Bléharies       102500.0      102500.0             313.31
# 246              Bailièvre       110000.0      110000.0             379.87
# 231           Baillonville       115000.0      125000.0             492.32
# ..                     ...            ...           ...                ...
# 344                 Chanly       750000.0      750000.0             122.19
# 345          Céroux-Mousty       760000.0      760000.0             450.72
# 297  Couture-Saint-Germain       785000.0      785000.0            1787.50
# 143               Bornival       950000.0      950000.0              37.27
# 206              Buvrinnes       995000.0      995000.0             843.22
#
# [372 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Wallonia? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area and Land Surface  compered to Average price per squares meters

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv")
localities_Wallonia= df.query("Region == 'Wallonia'")['Locality'].unique()

def expensive_locality_Wallonia(df):


    localities = df.query("Region == 'Wallonia'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Wallonia(df)
print(df_return)
df_return=expensive_locality_Wallonia(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 les expensive localities in Wallonia")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                   Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 143               Bornival       950000.0      950000.0              37.27
# 344                 Chanly       750000.0      750000.0             122.19
# 153               Bierwart       395000.0      395000.0             127.46
# 323                   Hour       340000.0      340000.0             158.88
# 369              Papignies       235000.0      235000.0             163.19
# ..                     ...            ...           ...                ...
# 297  Couture-Saint-Germain       785000.0      785000.0            1787.50
# 207      Fontaine-l'evêque       312000.0      345000.0            1799.42
# 289                 Bonlez       734577.8      757889.0            1901.04
# 3         Fontaine-Valmont       600000.0      600000.0            2264.15
# 174       Louvain-La-Neuve       236000.0      240000.0            2658.99
#
# [372 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Flanders? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area and Land Surface compered to Average price per squares meters

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv")

def expensive_locality_Flanders(df):


    localities = df.query("Region == 'Falnders'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Flanders(df)
print(df_return)

df_return=expensive_locality_Flanders(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 les expensive localities in Flanders")
plt.gca().invert_yaxis()
plt.show()
# Out:
#               Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 386           Kerkhove      225000.00      225000.0              72.91
# 307         Alveringem      257500.00      257500.0             279.11
# 220             Kaster      299500.00      299500.0             284.16
# 394           Everberg      370000.00      370000.0             285.94
# 277  Sint-Eloois-Vijve      475000.00      475000.0             289.28
# ..                 ...            ...           ...                ...
# 150           Koksijde      456570.00      377000.0            2076.48
# 79          Nieuwpoort      375525.64      285000.0            2166.43
# 9               Leuven      426707.32      415000.0            2356.19
# 135      Heist-Aan-Zee      516281.25      472000.0            2730.95
# 77              Knokke      688026.36      695000.0            4116.13
#
# [413 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Flanders? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area and Land Surface compered to Average price

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Cleaned_Data.csv')

def expensive_locality_Falnders(df):


    localities = df.query("Region == 'Falnders'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']+df['Land_Surface']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Flanders(df)
print(df_return)

df_return=expensive_locality_Flanders(df).head(10).sort_values('Average_Price', ascending=True)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'], color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average_Price")
plt.title("Top 10 les expensive localities in Flanders")
plt.gca().invert_yaxis()
plt.show()
# Out:
#               Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 386           Kerkhove      225000.00      225000.0              72.91
# 307         Alveringem      257500.00      257500.0             279.11
# 220             Kaster      299500.00      299500.0             284.16
# 394           Everberg      370000.00      370000.0             285.94
# 277  Sint-Eloois-Vijve      475000.00      475000.0             289.28
# ..                 ...            ...           ...                ...
# 150           Koksijde      456570.00      377000.0            2076.48
# 79          Nieuwpoort      375525.64      285000.0            2166.43
# 9               Leuven      426707.32      415000.0            2356.19
# 135      Heist-Aan-Zee      516281.25      472000.0            2730.95
# 77              Knokke      688026.36      695000.0            4116.13
#
# [413 rows x 4 columns]
