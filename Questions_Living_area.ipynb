# %% [markdown]
# # What are the **most** expensive municipalities in Belgium? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area   compered to Average Price

# %%
import pandas as pd
import matplotlib.pyplot as plt


def expensive_locality(df):


    localities = df['Locality'].unique()
    df['Surface_total']=df['Living_Area']
    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=False)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality(df)
print(df_return)

df_return=expensive_locality(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'],color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average Price")
plt.title("Top 10  most expensive localities in Belgium")
plt.gca().invert_yaxis()
plt.show()
# Out:
#           Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 785        Pollare       999000.0      999000.0            1986.08
# 549      Buvrinnes       995000.0      995000.0            1895.24
# 567      Kasterlee       957000.0      957000.0            3137.70
# 416       Bornival       950000.0      950000.0            3877.55
# 775  Borchtlombeek       949000.0      949000.0            4004.22
# ..             ...            ...           ...                ...
# 601   Baillonville       115000.0      125000.0            1913.68
# 626      Bailièvre       110000.0      110000.0             777.24
# 266      Bléharies       102500.0      102500.0             866.70
# 112      Grandrieu        95000.0       95000.0            1862.75
# 724     Asquillies        83500.0       83500.0             735.17
#
# [806 rows x 4 columns]

# %% [markdown]
# # What are the **most** expensive municipalities in Belgium? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area   compered to Average price per meters squares

# %%
import pandas as pd
def expensive_locality(df):


    localities = df['Locality'].unique()
    df['Surface_total']=df['Living_Area']
    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=False)


    return municipality_stats


df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality(df)
print(df_return)
df_return=expensive_locality(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 most expensive localities in Belgium")
plt.gca().invert_yaxis()
plt.show()
# Out:
#              Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 115            Knokke      688026.36      695000.0            8372.32
# 192          Oudergem      567138.92      568400.0            5842.90
# 228     Heist-Aan-Zee      516281.25      472000.0            5645.18
# 486  Louvain-La-Neuve      236000.00      240000.0            5354.97
# 461         Alsemberg      645000.00      645000.0            5243.90
# ..                ...            ...           ...                ...
# 618             Gouvy      160000.00      160000.0             715.24
# 518        Alveringem      257500.00      257500.0             682.58
# 700    Ramegnies-Chin      199000.00      199000.0             552.78
# 696       Bon-Secours      135000.00      135000.0             540.00
# 771           Amblève      356500.00      356500.0             461.32
#
# [806 rows x 4 columns]

# %% [markdown]
# # What are the most expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %% [markdown]
# Analysis done on the basis of  Living Area   compered to Average  per squares meters

# %%
import pandas as pd

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
localities_Wallonia= df.query("Region == 'Wallonia'")['Locality'].unique()

def expensive_locality_Wallonia(df):


    localities = df.query("Region == 'Wallonia'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=False)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Wallonia(df)
print(df_return)
df_return=expensive_locality_Wallonia(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 most expensive localities in Wallonia")
plt.gca().invert_yaxis()
plt.show()
# Out:
#               Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 174   Louvain-La-Neuve       236000.0      240000.0            5354.97
# 125  Lillois-Witterzée       620000.0      620000.0            5166.67
# 3     Fontaine-Valmont       600000.0      600000.0            4878.05
# 289             Bonlez       734577.8      757889.0            4797.09
# 143           Bornival       950000.0      950000.0            3877.55
# ..                 ...            ...           ...                ...
# 320         Asquillies        83500.0       83500.0             735.17
# 241              Gouvy       160000.0      160000.0             715.24
# 304     Ramegnies-Chin       199000.0      199000.0             552.78
# 300        Bon-Secours       135000.0      135000.0             540.00
# 352            Amblève       356500.0      356500.0             461.32
#
# [372 rows x 4 columns]

# %% [markdown]
# # What are the most expensive municipalities in Wallonia? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area   compered to Average Price

# %%
import pandas as pd

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
localities_Wallonia= df.query("Region == 'Wallonia'")['Locality'].unique()

def expensive_locality_Wallonia(df):

    localities = df.query("Region == 'Wallonia'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=False)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Wallonia(df)
print(df_return)

df_return=expensive_locality_Wallonia(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'], color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average_Price")
plt.title("Top 10 most expensive localities in Wallonia")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                   Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 206              Buvrinnes       995000.0      995000.0            1895.24
# 143               Bornival       950000.0      950000.0            3877.55
# 297  Couture-Saint-Germain       785000.0      785000.0            3575.00
# 345          Céroux-Mousty       760000.0      760000.0            3230.98
# 344                 Chanly       750000.0      750000.0            2884.62
# ..                     ...            ...           ...                ...
# 231           Baillonville       115000.0      125000.0            1913.68
# 246              Bailièvre       110000.0      110000.0             777.24
# 88               Bléharies       102500.0      102500.0             866.70
# 28               Grandrieu        95000.0       95000.0            1862.75
# 320             Asquillies        83500.0       83500.0             735.17
#
# [372 rows x 4 columns]

# %% [markdown]
# # What are the most expensive municipalities in Flanders? (Average price, median price, price per square meter)
#
# Analysis done on the basis of  Living Area  compered to Average Price

# %%
import pandas as pd

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')

def expensive_locality_Flanders(df):


    localities = df.query("Region == 'Falnders'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=False)


    return municipality_stats


df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Flanders(df)
print(df_return)
df_return=expensive_locality_Flanders(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'], color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average_Price")
plt.title("Top 10 most expensive localities in Flanders")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 404             Pollare      999000.00      999000.0            1986.08
# 332           Kasterlee      957000.00      957000.0            3137.70
# 399       Borchtlombeek      949000.00      949000.0            4004.22
# 54   Sint-martens-latem      878333.33      845000.0            3901.85
# 393          Middelburg      849000.00      849000.0            2122.50
# ..                  ...            ...           ...                ...
# 410            Heestert      176000.00      176000.0            1284.67
# 367            Langdorp      169000.00      169000.0            1352.00
# 153            Dadizele      168500.00      168500.0            1328.55
# 335               Rekem      129000.00      129000.0            1048.78
# 320             Bossuit      118000.00      118000.0             959.35
#
# [413 rows x 4 columns]

# %% [markdown]
# # What are the most expensive municipalities in Flanders? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area  compered to Average price per squares meters

# %%
import pandas as pd

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')

def expensive_locality_Flanders(df):


    localities = df.query("Region == 'Falnders'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=False)


    return municipality_stats


df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Flanders(df)
print(df_return)

df_return=expensive_locality_Flanders(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 most expensive localities in Flanders")
plt.gca().invert_yaxis()
plt.show()
# Out:
#           Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 77          Knokke      688026.36      695000.0            8372.32
# 135  Heist-Aan-Zee      516281.25      472000.0            5645.18
# 278      Alsemberg      645000.00      645000.0            5243.90
# 9           Leuven      426707.32      415000.0            4887.42
# 376       Duisburg      595000.00      685000.0            4741.10
# ..             ...            ...           ...                ...
# 298      Ruiselede      220000.00      220000.0             973.45
# 320        Bossuit      118000.00      118000.0             959.35
# 70        Boezinge      189000.00      189000.0             949.75
# 209       Kaprijke      435000.00      435000.0             870.00
# 307     Alveringem      257500.00      257500.0             682.58
#
# [413 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Belgium? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area   compered to Average price

# %%
import pandas as pd
def expensive_locality(df):


    localities = df['Locality'].unique()
    df['Surface_total']=df['Living_Area']
    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality(df)
print(df_return)

df_return=expensive_locality(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'],  color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average Price")
plt.title("Top 10 less expensive localities in Belgium")
plt.gca().invert_yaxis()
plt.show()
# Out:
#           Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 724     Asquillies        83500.0       83500.0             735.17
# 112      Grandrieu        95000.0       95000.0            1862.75
# 266      Bléharies       102500.0      102500.0             866.70
# 626      Bailièvre       110000.0      110000.0             777.24
# 601   Baillonville       115000.0      125000.0            1913.68
# ..             ...            ...           ...                ...
# 775  Borchtlombeek       949000.0      949000.0            4004.22
# 416       Bornival       950000.0      950000.0            3877.55
# 567      Kasterlee       957000.0      957000.0            3137.70
# 549      Buvrinnes       995000.0      995000.0            1895.24
# 785        Pollare       999000.0      999000.0            1986.08
#
# [806 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Belgium? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area   compered to Average per squares meters

# %%
import pandas as pd
def expensive_locality(df):


    localities = df['Locality'].unique()
    df['Surface_total']=df['Living_Area']
    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality(df)
print(df_return)

df_return=expensive_locality(df).head(10).sort_values('Avg_Price_per_SqM',ascending=True)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 less expensive localities in Belgium")
plt.gca().invert_yaxis()
plt.show()
# Out:
#              Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 771           Amblève      356500.00      356500.0             461.32
# 696       Bon-Secours      135000.00      135000.0             540.00
# 700    Ramegnies-Chin      199000.00      199000.0             552.78
# 518        Alveringem      257500.00      257500.0             682.58
# 618             Gouvy      160000.00      160000.0             715.24
# ..                ...            ...           ...                ...
# 461         Alsemberg      645000.00      645000.0            5243.90
# 486  Louvain-La-Neuve      236000.00      240000.0            5354.97
# 228     Heist-Aan-Zee      516281.25      472000.0            5645.18
# 192          Oudergem      567138.92      568400.0            5842.90
# 115            Knokke      688026.36      695000.0            8372.32
#
# [806 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Wallonia? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area   compered to Average price

# %%
import pandas as pd

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
localities_Wallonia= df.query("Region == 'Wallonia'")['Locality'].unique()

def expensive_locality_Wallonia(df):


    localities = df.query("Region == 'Wallonia'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Wallonia(df)
print(df_return)
df_return=expensive_locality_Wallonia(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'], color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average_Price")
plt.title("Top 10 les expensive localities in Wallonia")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                   Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 320             Asquillies        83500.0       83500.0             735.17
# 28               Grandrieu        95000.0       95000.0            1862.75
# 88               Bléharies       102500.0      102500.0             866.70
# 246              Bailièvre       110000.0      110000.0             777.24
# 231           Baillonville       115000.0      125000.0            1913.68
# ..                     ...            ...           ...                ...
# 344                 Chanly       750000.0      750000.0            2884.62
# 345          Céroux-Mousty       760000.0      760000.0            3230.98
# 297  Couture-Saint-Germain       785000.0      785000.0            3575.00
# 143               Bornival       950000.0      950000.0            3877.55
# 206              Buvrinnes       995000.0      995000.0            1895.24
#
# [372 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Wallonia? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area   compered to Average per squares

# %%
import pandas as pd

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
localities_Wallonia= df.query("Region == 'Wallonia'")['Locality'].unique()

def expensive_locality_Wallonia(df):


    localities = df.query("Region == 'Wallonia'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Wallonia(df)
print(df_return)
df_return=expensive_locality_Wallonia(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 les expensive localities in Wallonia")
plt.gca().invert_yaxis()
plt.show()
# Out:
#               Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 352            Amblève       356500.0      356500.0             461.32
# 300        Bon-Secours       135000.0      135000.0             540.00
# 304     Ramegnies-Chin       199000.0      199000.0             552.78
# 241              Gouvy       160000.0      160000.0             715.24
# 320         Asquillies        83500.0       83500.0             735.17
# ..                 ...            ...           ...                ...
# 143           Bornival       950000.0      950000.0            3877.55
# 289             Bonlez       734577.8      757889.0            4797.09
# 3     Fontaine-Valmont       600000.0      600000.0            4878.05
# 125  Lillois-Witterzée       620000.0      620000.0            5166.67
# 174   Louvain-La-Neuve       236000.0      240000.0            5354.97
#
# [372 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Flanders? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area   compered to Average per squares

# %%
import pandas as pd

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')

def expensive_locality_Flanders(df):


    localities = df.query("Region == 'Falnders'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
    
        municipality_stats = municipality_stats.sort_values(by='Avg_Price_per_SqM', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Flanders(df)
print(df_return)

df_return=expensive_locality_Flanders(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Avg_Price_per_SqM'], color='#2A9D8F')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Avg_Price_per_SqM")
plt.title("Top 10 les expensive localities in Flanders")
plt.gca().invert_yaxis()
plt.show()
# Out:
#           Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 307     Alveringem      257500.00      257500.0             682.58
# 209       Kaprijke      435000.00      435000.0             870.00
# 70        Boezinge      189000.00      189000.0             949.75
# 320        Bossuit      118000.00      118000.0             959.35
# 298      Ruiselede      220000.00      220000.0             973.45
# ..             ...            ...           ...                ...
# 376       Duisburg      595000.00      685000.0            4741.10
# 9           Leuven      426707.32      415000.0            4887.42
# 278      Alsemberg      645000.00      645000.0            5243.90
# 135  Heist-Aan-Zee      516281.25      472000.0            5645.18
# 77          Knokke      688026.36      695000.0            8372.32
#
# [413 rows x 4 columns]

# %% [markdown]
# # What are the less expensive municipalities in Flanders? (Average price, median price, price per square meter)
# Analysis done on the basis of  Living Area  compered to Average price

# %%
import pandas as pd

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')

def expensive_locality_Flanders(df):


    localities = df.query("Region == 'Falnders'")['Locality'].unique()
    df['Surface_total']=df['Living_Area']

    results = []

    for locality in localities:
    
        locality_data = df[df['Locality'] == locality]

        average_price = locality_data['Price'].mean()
        median_price = locality_data['Price'].median()
        
        valid_surface_data = locality_data[locality_data['Surface_total'] > 0]  
        if not valid_surface_data.empty:
            price_per_square_meter = (valid_surface_data['Price'] / valid_surface_data['Surface_total']).mean()
        else:

             price_per_square_meter = None  

      
        results.append({
            'Locality': locality,
            'Average_Price': round(average_price, 2),
            'Median_Price': round(median_price, 2),
            'Avg_Price_per_SqM': round(price_per_square_meter, 2) if price_per_square_meter is not None else None
        })
        municipality_stats = pd.DataFrame(results)
        municipality_stats = municipality_stats.sort_values(by='Average_Price', ascending=True)


    return municipality_stats

df=pd.read_csv('C:/Users/ilasv/ImmoEliza-Analysis/Semi_final_data.csv')
df_return=expensive_locality_Flanders(df)
print(df_return)

df_return=expensive_locality_Flanders(df).head(10)
# Create a bar chart
plt.barh(df_return['Locality'], df_return['Average_Price'], color='#780000')
plt.xticks(rotation=90)  # Rotate labels for better readability
plt.ylabel("Locality")
plt.xlabel("Average_Price")
plt.title("Top 10 les expensive localities in Flanders")
plt.gca().invert_yaxis()
plt.show()
# Out:
#                Locality  Average_Price  Median_Price  Avg_Price_per_SqM
# 320             Bossuit      118000.00      118000.0             959.35
# 335               Rekem      129000.00      129000.0            1048.78
# 153            Dadizele      168500.00      168500.0            1328.55
# 367            Langdorp      169000.00      169000.0            1352.00
# 410            Heestert      176000.00      176000.0            1284.67
# ..                  ...            ...           ...                ...
# 393          Middelburg      849000.00      849000.0            2122.50
# 54   Sint-martens-latem      878333.33      845000.0            3901.85
# 399       Borchtlombeek      949000.00      949000.0            4004.22
# 332           Kasterlee      957000.00      957000.0            3137.70
# 404             Pollare      999000.00      999000.0            1986.08
#
# [413 rows x 4 columns]
