# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import folium
from folium.plugins import HeatMap
from sklearn.preprocessing import LabelEncoder
import os

# %%
df=pd.read_csv("/home/learner/Desktop/Data Anlaysis/ImmoEliza-Analysis/Final_cleaned_Data.csv")

# %%
df
# Out:
#        Unnamed: 0        Id        Locality       Type    SubType   Price  \
# 0               0  20316087        Ertvelde      House      house  329000
# 1               1  20316069           Hornu      House      house  180000
# 2               2  20316048         Beersel      House      house  369000
# 3               3  20316039  Geraardsbergen      House      house  145000
# 4               4  20316038  Geraardsbergen      House      house  269000
# ...           ...       ...             ...        ...        ...     ...
# 10679       10679   8972064    Blankenberge  Apartment  apartment  324146
# 10680       10680   8945382          Knokke  Apartment     duplex  699000
# 10681       10681   8746466          Knokke  Apartment  apartment  950000
# 10682       10682   8498727    Ingelmunster  Apartment  apartment  562500
# 10683       10683   7961536         Aarsele  Apartment  apartment  305000
#
#        Bedrooms  Living_Area  Is_Equiped_Kitchen  Is_Furnished  ...  \
# 0             2          123                   1             0  ...
# 1             3          138                   0             0  ...
# 2             6          230                   0             0  ...
# 3             2           80                   1             0  ...
# 4             3          155                   1             0  ...
# ...         ...          ...                 ...           ...  ...
# 10679         2           82                   0             0  ...
# 10680         4          129                   0             0  ...
# 10681         2          157                   0             0  ...
# 10682         3          190                   0             0  ...
# 10683         2           70                   1             0  ...
#
#        Garden_Area  Land_Surface  State  Facades  Swim_pool      Muniplicity  \
# 0                0           142      1        3          0  Oost-Vlaanderen
# 1                1           140      3        2          1       Henegouwen
# 2                0           230      5        3          1   Vlaams-Brabant
# 3                0            80      1        2          0  Oost-Vlaanderen
# 4              170           345      1        2          0  Oost-Vlaanderen
# ...            ...           ...    ...      ...        ...              ...
# 10679            0            89      1        0          0  West-Vlaanderen
# 10680            0           129      3        0          0  West-Vlaanderen
# 10681            0           157      3        2          0  West-Vlaanderen
# 10682            0           190      1        0          0  West-Vlaanderen
# 10683            0            70      1        0          0  West-Vlaanderen
#
#          Region  Surface_total          X         Y
# 0      Flanders              0  51.120406  3.707520
# 1      Wallonia            278  50.423926  3.820832
# 2      Flanders            460  50.766251  4.312619
# 3      Flanders            160  50.820984  3.886864
# 4      Flanders            500  50.820984  3.886864
# ...         ...            ...        ...       ...
# 10679  Flanders            171  51.298379  3.141601
# 10680  Flanders            258  51.346652  3.331958
# 10681  Flanders            314  51.346652  3.331958
# 10682  Flanders            380  50.921458  3.260685
# 10683  Flanders            140  50.999978  3.337407
#
# [10684 rows x 24 columns]

# %%
Top_localities = df.groupby("Region").Living_Area.mean().astype(int)

# Plotting the bar chart
Top_localities.plot(kind='bar', color='skyblue', edgecolor="navy")

# Add numbers to each bar
for index, value in enumerate(Top_localities):
    plt.text(index, value + 0.1, str(value), ha='center', va='bottom', fontsize=10)

# Customize the plot
plt.title('Avg space per region', fontsize=16)
plt.xlabel('Region')
plt.ylabel('Area pr sqrd m')
plt.grid(axis='y', linestyle='--', alpha=1)

# Create 'graphs' directory if it doesn't exist
if not os.path.exists('graphs'):
    os.makedirs('graphs')

# Save the plot as an image
plt.savefig('graphs/top_localities.png', bbox_inches='tight')  # Save as PNG in the 'graphs' folder

# Show the plot (optional, if you also want to display it interactively)
plt.show()
